# %% [markdown]
# ## Cleaning and analyzing datasets
#
# Previously, I scraped `.xlsx` files from the New York Police Department's page on [Hate Crimes Reports](https://www.nyc.gov/site/nypd/stats/reports-analysis/hate-crimes.page). This time, I will be cleaning and analyzing the datasets downloaded.
#
# _(Note: I manually created a new folder to organize the files that were downloaded and I previewed the datasets to figure out which ones I wanted to use.)_

# %% [markdown]
# #### Hate crime complaints by motivation
#
# The datasets cover 2020-2023 by quarter and by year, and only the first quarter for 2024. I've decided to use the quarterly breakdowns to hopefully see nuances in the data, e.g., a possible spike in anti-Asian sentiments at the onset of Covid-19 and in anti-Jewish sentiments during the Israel-Palestine war.

# %%
# Start by setting up libraries

import pandas as pd
import numpy
import matplotlib.pyplot as plt

# %% [markdown]
# #### Q1, 2020
#
# Observed issues: The dataset has four rows that contain text as title and description of the dataset. I used `skiprows` to remove these unnecessary rows.

# %%
df = pd.read_excel('downloaded-datasets/hate-crime-complaints-by-motivation-q1-202020.xlsx', skiprows=4)
df.dtypes
# Out:
# Precinct                                 object
# Anti-Asian                              float64
# Anti-Black                              float64
# Anti-Catholic                           float64
# Anti-Female Homosexual (Lesbian)        float64
# Anti-Hindu                              float64
# Anti-Islamic (Muslim)                   float64
# Anti-Jewish                             float64
# Anti-Male Homosexual (Gay)              float64
# Anti-Other Ethnicity/National Origin    float64
# Anti-Transgender                        float64
# Anti-White                              float64
# Total                                   float64
# dtype: object

# %%
# Get only the totals, which are in the last row

last_row = df.tail(1)

# %%
# Create a new DF for totals

totals_df = pd.DataFrame(last_row)
totals_df['period'] = '2020, Q1'

# %%
# This makes reindexing of later DFs easier...

totals_df.columns = totals_df.columns.str.lower().str.strip()

# %%
# Renaming columns for consistency... 

totals_df = totals_df.rename(columns={'anti-female homosexual (lesbian)': 'anti-lesbian', 'anti-male homosexual (gay)': 'anti-gay', 'anti-islamic (muslim)': 'anti-muslim', 'anti-other ethnicity/national origin': 'anti-other ethnicity'})

# %%
# totals_df.drop(['precinct'], axis=1)
# totals_df.drop(totals_df.columns[0], axis=1)

# %%
# Save as CSV for checkpoint

totals_df.to_csv('totals.csv')

# %% [markdown]
# #### Q2, 2020
#
# Observed issues: The column names are capitalized and not in the same order as those of `Q1, 2020`. Some column names also do not exist or are stated differently than that of the previous dataset, so I had to `rename` some columns in this dataset and the previous one.
#
# Aside from the first four rows to skip, the **totals** in this dataset are also not in the last row, so I cannot simply use `.tail(1)`.

# %%
df = pd.read_excel('downloaded-datasets/hate-crime-complaints-by-motivation-q2-202020.xlsx', skiprows=4)
df.dtypes
# Out:
# PRECINCT                              object
# 60 YEARS OLD OR MORE                 float64
# ANTI-ARAB                            float64
# ANTI-ASIAN                           float64
# ANTI-BLACK                           float64
# ANTI-CATHOLIC                        float64
# ANTI-FEMALE                          float64
# ANTI-FEMALE HOMOSEXUAL\n(LESBIAN)    float64
# ANTI-GENDER NON-CONFORMING           float64
# ANTI-HINDU                           float64
# ANTI-HISPANIC                        float64
# ANTI-ISLAMIC\n(MUSLIM)               float64
# ANTI-JEWISH                          float64
# ANTI-MALE HOMOSEXUAL\n(GAY)          float64
# ANTI-OTHER ETHNICITY                 float64
# ANTI-TRANSGENDER                     float64
# ANTI-WHITE                           float64
# Total                                float64
# dtype: object

# %%
df.columns = df.columns.str.lower().str.strip()
df.columns = df.columns.str.replace('\n', '')

# %%
# Drop unnecessary rows

df.drop(df.tail(4).index, inplace=True)

# %%
# Get only the totals, which are NOW the last row

last_row = df.tail(1)

# %%
last_row['period'] = '2020, Q2'
# Out:
# /var/folders/4f/fk_hbgy14cg47tw521m3y0xw0000gn/T/ipykernel_54677/2065008592.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_row['period'] = '2020, Q2'

# %%
# Renaming columns for consistency... 

last_row = last_row.rename(columns={'anti-female homosexual(lesbian)': 'anti-lesbian', 'anti-male homosexual(gay)': 'anti-gay', 'anti-islamic(muslim)': 'anti-muslim'})

# %%
# Check and align columns

common_columns = totals_df.columns.intersection(last_row.columns)
common_columns
# Out:
# Index(['precinct', 'anti-asian', 'anti-black', 'anti-catholic', 'anti-lesbian',
#        'anti-hindu', 'anti-muslim', 'anti-jewish', 'anti-gay',
#        'anti-other ethnicity', 'anti-transgender', 'anti-white', 'total',
#        'period'],
#       dtype='object')

# %%
# Check different columns

diff_columns1 = last_row.columns.difference(totals_df.columns)
diff_columns1
# Out:
# Index(['60 years old or more', 'anti-arab', 'anti-female',
#        'anti-gender non-conforming', 'anti-hispanic'],
#       dtype='object')

# %%
totals_df = pd.concat([totals_df, last_row], ignore_index=True)
totals_df
# Out:
#   precinct  anti-asian  anti-black  anti-catholic  anti-lesbian  anti-hindu  \
# 0    Total        11.0        12.0            1.0           1.0         1.0
# 1    Total         8.0         5.0            3.0           2.0         1.0
#
#    anti-muslim  anti-jewish  anti-gay  anti-other ethnicity  anti-transgender  \
# 0          1.0         45.0       5.0                   3.0               2.0
# 1          0.0         15.0       4.0                   1.0               1.0
#
#    anti-white  total    period  60 years old or more  anti-arab  anti-female  \
# 0         2.0   84.0  2020, Q1                   NaN        NaN          NaN
# 1         2.0   46.0  2020, Q2                   1.0        1.0          0.0
#
#    anti-gender non-conforming  anti-hispanic
# 0                         NaN            NaN
# 1                         2.0            0.0

# %% [markdown]
# #### Q3, 2020

# %%
df = pd.read_excel('downloaded-datasets/hate-crime-complaints-by-motivation-q3-2020.xlsx', skiprows=4)
df.dtypes
# Out:
# PRECINCT                             object
# ANTI-ASIAN                            int64
# ANTI-BLACK                            int64
# ANTI-CATHOLIC                         int64
# ANTI-JEWISH                           int64
# ANTI-LGBT (MIXED GROUP)               int64
# ANTI-MALE HOMOSEXUAL (GAY)            int64
# ANTI-MULTI RACIAL GROUPS              int64
# ANTI-OTHER ETHNICITY                  int64
# ANTI-RELIGIOUS PRACTICE GENERALLY     int64
# ANTI-TRANSGENDER                      int64
# ANTI-WHITE                            int64
# Total                                 int64
# dtype: object

# %%
df.columns = df.columns.str.lower().str.strip()
df.columns = df.columns.str.replace('\n', '')

# %%
last_row = df.tail(1)
last_row['period'] = '2020, Q3'
# Out:
# /var/folders/4f/fk_hbgy14cg47tw521m3y0xw0000gn/T/ipykernel_54677/4190589498.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_row['period'] = '2020, Q3'

# %%
last_row = last_row.rename(columns={'anti-lgbt (mixed group)': 'anti-lgbt', 'anti-male homosexual (gay)': 'anti-gay', 'anti-islamic(muslim)': 'anti-muslim'})

# %%
common_columns = totals_df.columns.intersection(last_row.columns)
common_columns
# Out:
# Index(['precinct', 'anti-asian', 'anti-black', 'anti-catholic', 'anti-jewish',
#        'anti-gay', 'anti-other ethnicity', 'anti-transgender', 'anti-white',
#        'total', 'period'],
#       dtype='object')

# %%
diff_columns1 = last_row.columns.difference(totals_df.columns)
diff_columns1
# Out:
# Index(['anti-lgbt', 'anti-multi racial groups',
#        'anti-religious practice generally'],
#       dtype='object')

# %%
totals_df = pd.concat([totals_df, last_row], ignore_index=True)
totals_df
# Out:
#   precinct  anti-asian  anti-black  anti-catholic  anti-lesbian  anti-hindu  \
# 0    Total        11.0        12.0            1.0           1.0         1.0
# 1    Total         8.0         5.0            3.0           2.0         1.0
# 2    Total         4.0        16.0            3.0           NaN         NaN
#
#    anti-muslim  anti-jewish  anti-gay  anti-other ethnicity  ...  total  \
# 0          1.0         45.0       5.0                   3.0  ...   84.0
# 1          0.0         15.0       4.0                   1.0  ...   46.0
# 2          NaN         28.0       8.0                   1.0  ...   75.0
#
#      period  60 years old or more anti-arab  anti-female  \
# 0  2020, Q1                   NaN       NaN          NaN
# 1  2020, Q2                   1.0       1.0          0.0
# 2  2020, Q3                   NaN       NaN          NaN
#
#    anti-gender non-conforming  anti-hispanic  anti-lgbt  \
# 0                         NaN            NaN        NaN
# 1                         2.0            0.0        NaN
# 2                         NaN            NaN        4.0
#
#    anti-multi racial groups  anti-religious practice generally
# 0                       NaN                                NaN
# 1                       NaN                                NaN
# 2                       2.0                                2.0
#
# [3 rows x 22 columns]

# %% [markdown]
# #### Q4, 2020

# %%
df = pd.read_excel('downloaded-datasets/hate-crime-complaints-by-motivation-q4-2020.xlsx', skiprows=4)
df.dtypes
# Out:
# PRECINCT                             object
# ANTI-ASIAN                            int64
# ANTI-BLACK                            int64
# ANTI-CATHOLIC                         int64
# ANTI-FEMALE                           int64
# ANTI-FEMALE HOMOSEXUAL\n(LESBIAN)     int64
# ANTI-HISPANIC                         int64
# ANTI-ISLAMIC\n(MUSLIM)                int64
# ANTI-JEWISH                           int64
# ANTI-MALE HOMOSEXUAL\n(GAY)           int64
# ANTI-OTHER ETHNICITY                  int64
# ANTI-WHITE                            int64
# Total                                 int64
# dtype: object

# %%
df.columns = df.columns.str.lower().str.strip()
df.columns = df.columns.str.replace('\n', '')

# %%
last_row = df.tail(1)
last_row['period'] = '2020, Q4'
# Out:
# /var/folders/4f/fk_hbgy14cg47tw521m3y0xw0000gn/T/ipykernel_54677/1596762532.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_row['period'] = '2020, Q4'

# %%
last_row = last_row.rename(columns={'anti-female homosexual(lesbian)': 'anti-lesbian', 'anti-male homosexual(gay)': 'anti-gay', 'anti-islamic(muslim)': 'anti-muslim'})

# %%
common_columns = totals_df.columns.intersection(last_row.columns)
common_columns
# Out:
# Index(['precinct', 'anti-asian', 'anti-black', 'anti-catholic', 'anti-lesbian',
#        'anti-muslim', 'anti-jewish', 'anti-gay', 'anti-other ethnicity',
#        'anti-white', 'total', 'period', 'anti-female', 'anti-hispanic'],
#       dtype='object')

# %%
diff_columns1 = last_row.columns.difference(totals_df.columns)
diff_columns1
# Out:
# Index([], dtype='object')

# %%
totals_df = pd.concat([totals_df, last_row], ignore_index=True)
totals_df
# Out:
#   precinct  anti-asian  anti-black  anti-catholic  anti-lesbian  anti-hindu  \
# 0    Total        11.0        12.0            1.0           1.0         1.0
# 1    Total         8.0         5.0            3.0           2.0         1.0
# 2    Total         4.0        16.0            3.0           NaN         NaN
# 3    Total         3.0         8.0            1.0           1.0         NaN
#
#    anti-muslim  anti-jewish  anti-gay  anti-other ethnicity  ...  total  \
# 0          1.0         45.0       5.0                   3.0  ...   84.0
# 1          0.0         15.0       4.0                   1.0  ...   46.0
# 2          NaN         28.0       8.0                   1.0  ...   75.0
# 3          3.0         28.0       8.0                   1.0  ...   60.0
#
#      period  60 years old or more anti-arab  anti-female  \
# 0  2020, Q1                   NaN       NaN          NaN
# 1  2020, Q2                   1.0       1.0          0.0
# 2  2020, Q3                   NaN       NaN          NaN
# 3  2020, Q4                   NaN       NaN          5.0
#
#    anti-gender non-conforming  anti-hispanic  anti-lgbt  \
# 0                         NaN            NaN        NaN
# 1                         2.0            0.0        NaN
# 2                         NaN            NaN        4.0
# 3                         NaN            1.0        NaN
#
#    anti-multi racial groups  anti-religious practice generally
# 0                       NaN                                NaN
# 1                       NaN                                NaN
# 2                       2.0                                2.0
# 3                       NaN                                NaN
#
# [4 rows x 22 columns]

# %% [markdown]
# #### Q1, 2021
#
# Observed issue: The filename of the dataset was misspelled, i.e. "motiviation"

# %%
df = pd.read_excel('downloaded-datasets/hate-crime-complaints-by-motiviation-q1-2021.xlsx', skiprows=4)
df.dtypes
# Out:
# PRECINCT                            object
# ANTI-ASIAN                           int64
# ANTI-BLACK                           int64
# ANTI-FEMALE                          int64
# ANTI-FEMALE HOMOSEXUAL (LESBIAN)     int64
# ANTI-HISPANIC                        int64
# ANTI-JEWISH                          int64
# ANTI-LGBT (MIXED GROUP)              int64
# ANTI-MALE HOMOSEXUAL (GAY)           int64
# ANTI-MUSLIM                          int64
# ANTI-OTHER ETHNICITY                 int64
# ANTI-TRANSGENDER                     int64
# Grand Total                          int64
# dtype: object

# %%
df.columns = df.columns.str.lower().str.strip()
df.columns = df.columns.str.replace('\n', '')

# %%
last_row = df.tail(1)
last_row['period'] = '2021, Q1'
# Out:
# /var/folders/4f/fk_hbgy14cg47tw521m3y0xw0000gn/T/ipykernel_54677/3486932570.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_row['period'] = '2021, Q1'

# %%
last_row = last_row.rename(columns={'anti-female homosexual (lesbian)': 'anti-lesbian', 'anti-male homosexual (gay)': 'anti-gay', 'anti-lgbt (mixed group)': 'anti-lgbt'})

# %%
common_columns = totals_df.columns.intersection(last_row.columns)
common_columns
# Out:
# Index(['precinct', 'anti-asian', 'anti-black', 'anti-lesbian', 'anti-muslim',
#        'anti-jewish', 'anti-gay', 'anti-other ethnicity', 'anti-transgender',
#        'period', 'anti-female', 'anti-hispanic', 'anti-lgbt'],
#       dtype='object')

# %%
diff_columns1 = last_row.columns.difference(totals_df.columns)
diff_columns1
# Out:
# Index(['grand total'], dtype='object')

# %%
totals_df = pd.concat([totals_df, last_row], ignore_index=True)
totals_df
# Out:
#       precinct  anti-asian  anti-black  anti-catholic  anti-lesbian  \
# 0        Total        11.0        12.0            1.0           1.0
# 1        Total         8.0         5.0            3.0           2.0
# 2        Total         4.0        16.0            3.0           NaN
# 3        Total         3.0         8.0            1.0           1.0
# 4  Grand Total        42.0        12.0            NaN           1.0
#
#    anti-hindu  anti-muslim  anti-jewish  anti-gay  anti-other ethnicity  ...  \
# 0         1.0          1.0         45.0       5.0                   3.0  ...
# 1         1.0          0.0         15.0       4.0                   1.0  ...
# 2         NaN          NaN         28.0       8.0                   1.0  ...
# 3         NaN          3.0         28.0       8.0                   1.0  ...
# 4         NaN          1.0         27.0       4.0                   2.0  ...
#
#      period  60 years old or more  anti-arab anti-female  \
# 0  2020, Q1                   NaN        NaN         NaN
# 1  2020, Q2                   1.0        1.0         0.0
# 2  2020, Q3                   NaN        NaN         NaN
# 3  2020, Q4                   NaN        NaN         5.0
# 4  2021, Q1                   NaN        NaN         3.0
#
#    anti-gender non-conforming  anti-hispanic  anti-lgbt  \
# 0                         NaN            NaN        NaN
# 1                         2.0            0.0        NaN
# 2                         NaN            NaN        4.0
# 3                         NaN            1.0        NaN
# 4                         NaN            1.0        1.0
#
#    anti-multi racial groups  anti-religious practice generally  grand total
# 0                       NaN                                NaN          NaN
# 1                       NaN                                NaN          NaN
# 2                       2.0                                2.0          NaN
# 3                       NaN                                NaN          NaN
# 4                       NaN                                NaN         96.0
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Q2, 2021
#
# Observed issue: Only one column name was different from that of the previous datasets.

# %%
df = pd.read_excel('downloaded-datasets/hate-crime-complaints-by-motivation-q2-2021.xlsx', skiprows=4)
df.dtypes
# Out:
# PRECINCT                            object
# ANTI-ASIAN                           int64
# ANTI-WHITE                           int64
# ANTI-CATHOLIC                        int64
# ANTI-BLACK                           int64
# ANTI-FEMALE                          int64
# ANTI-GENDER NON CONFORMING           int64
# ANTI-FEMALE HOMOSEXUAL (LESBIAN)     int64
# ANTI-HISPANIC                        int64
# ANTI-JEWISH                          int64
# ANTI-LGBT (MIXED GROUP)              int64
# ANTI-MALE HOMOSEXUAL (GAY)           int64
# ANTI-MUSLIM                          int64
# ANTI-OTHER ETHNICITY                 int64
# ANTI-TRANSGENDER                     int64
# Grand Total                          int64
# dtype: object

# %%
df.columns = df.columns.str.lower().str.strip()
df.columns = df.columns.str.replace('\n', '')

# %%
last_row = df.tail(1)
last_row['period'] = '2021, Q2'
# Out:
# /var/folders/4f/fk_hbgy14cg47tw521m3y0xw0000gn/T/ipykernel_54677/767617593.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_row['period'] = '2021, Q2'

# %%
last_row = last_row.rename(columns={'anti-gender non conforming': 'anti-gender non-conforming', 'anti-female homosexual (lesbian)': 'anti-lesbian', 'anti-male homosexual (gay)': 'anti-gay', 'anti-lgbt (mixed group)': 'anti-lgbt'})

# %%
common_columns = totals_df.columns.intersection(last_row.columns)
common_columns
# Out:
# Index(['precinct', 'anti-asian', 'anti-black', 'anti-catholic', 'anti-lesbian',
#        'anti-muslim', 'anti-jewish', 'anti-gay', 'anti-other ethnicity',
#        'anti-transgender', 'anti-white', 'period', 'anti-female',
#        'anti-gender non-conforming', 'anti-hispanic', 'anti-lgbt',
#        'grand total'],
#       dtype='object')

# %%
diff_columns1 = last_row.columns.difference(totals_df.columns)
diff_columns1
# Out:
# Index([], dtype='object')

# %%
totals_df = pd.concat([totals_df, last_row], ignore_index=True)
totals_df
# Out:
#       precinct  anti-asian  anti-black  anti-catholic  anti-lesbian  \
# 0        Total        11.0        12.0            1.0           1.0
# 1        Total         8.0         5.0            3.0           2.0
# 2        Total         4.0        16.0            3.0           NaN
# 3        Total         3.0         8.0            1.0           1.0
# 4  Grand Total        42.0        12.0            NaN           1.0
# 5  Grand Total        63.0        17.0            4.0           0.0
#
#    anti-hindu  anti-muslim  anti-jewish  anti-gay  anti-other ethnicity  ...  \
# 0         1.0          1.0         45.0       5.0                   3.0  ...
# 1         1.0          0.0         15.0       4.0                   1.0  ...
# 2         NaN          NaN         28.0       8.0                   1.0  ...
# 3         NaN          3.0         28.0       8.0                   1.0  ...
# 4         NaN          1.0         27.0       4.0                   2.0  ...
# 5         NaN          5.0         85.0      29.0                   2.0  ...
#
#      period  60 years old or more  anti-arab anti-female  \
# 0  2020, Q1                   NaN        NaN         NaN
# 1  2020, Q2                   1.0        1.0         0.0
# 2  2020, Q3                   NaN        NaN         NaN
# 3  2020, Q4                   NaN        NaN         5.0
# 4  2021, Q1                   NaN        NaN         3.0
# 5  2021, Q2                   NaN        NaN         0.0
#
#    anti-gender non-conforming  anti-hispanic  anti-lgbt  \
# 0                         NaN            NaN        NaN
# 1                         2.0            0.0        NaN
# 2                         NaN            NaN        4.0
# 3                         NaN            1.0        NaN
# 4                         NaN            1.0        1.0
# 5                         2.0            2.0        1.0
#
#    anti-multi racial groups  anti-religious practice generally  grand total
# 0                       NaN                                NaN          NaN
# 1                       NaN                                NaN          NaN
# 2                       2.0                                2.0          NaN
# 3                       NaN                                NaN          NaN
# 4                       NaN                                NaN         96.0
# 5                       NaN                                NaN        226.0
#
# [6 rows x 23 columns]

# %% [markdown]
# #### Q3, 2021

# %%
df = pd.read_excel('downloaded-datasets/hate-crime-complaints-by-motivation-q3-2021.xlsx', skiprows=4)
df.dtypes
# Out:
# PRECINCT                            object
# ANTI-ASIAN                           int64
# ANTI-WHITE                           int64
# ANTI-ARAB                            int64
# ANTI-CATHOLIC                        int64
# ANTI-BLACK                           int64
# ANTI-FEMALE                          int64
# ANTI-GENDER NON CONFORMING           int64
# ANTI-FEMALE HOMOSEXUAL (LESBIAN)     int64
# ANTI-HISPANIC                        int64
# ANTI-JEWISH                          int64
# ANTI-LGBT (MIXED GROUP)              int64
# ANTI-MALE HOMOSEXUAL (GAY)           int64
# ANTI-MUSLIM                          int64
# ANTI-OTHER ETHNICITY                 int64
# ANTI-TRANSGENDER                     int64
# Grand Total                          int64
# dtype: object

# %%
df.columns = df.columns.str.lower().str.strip()
df.columns = df.columns.str.replace('\n', '')

# %%
last_row = df.tail(1)
last_row['period'] = '2021, Q3'
# Out:
# /var/folders/4f/fk_hbgy14cg47tw521m3y0xw0000gn/T/ipykernel_54677/2826556745.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_row['period'] = '2021, Q3'

# %%
last_row = last_row.rename(columns={'anti-gender non conforming': 'anti-gender non-conforming', 'anti-female homosexual (lesbian)': 'anti-lesbian', 'anti-male homosexual (gay)': 'anti-gay', 'anti-lgbt (mixed group)': 'anti-lgbt'})

# %%
common_columns = totals_df.columns.intersection(last_row.columns)
common_columns
# Out:
# Index(['precinct', 'anti-asian', 'anti-black', 'anti-catholic', 'anti-lesbian',
#        'anti-muslim', 'anti-jewish', 'anti-gay', 'anti-other ethnicity',
#        'anti-transgender', 'anti-white', 'period', 'anti-arab', 'anti-female',
#        'anti-gender non-conforming', 'anti-hispanic', 'anti-lgbt',
#        'grand total'],
#       dtype='object')

# %%
diff_columns1 = last_row.columns.difference(totals_df.columns)
diff_columns1
# Out:
# Index([], dtype='object')

# %%
totals_df = pd.concat([totals_df, last_row], ignore_index=True)
totals_df
# Out:
#       precinct  anti-asian  anti-black  anti-catholic  anti-lesbian  \
# 0        Total        11.0        12.0            1.0           1.0
# 1        Total         8.0         5.0            3.0           2.0
# 2        Total         4.0        16.0            3.0           NaN
# 3        Total         3.0         8.0            1.0           1.0
# 4  Grand Total        42.0        12.0            NaN           1.0
# 5  Grand Total        63.0        17.0            4.0           0.0
# 6  Grand Total        20.0         7.0            4.0           2.0
#
#    anti-hindu  anti-muslim  anti-jewish  anti-gay  anti-other ethnicity  ...  \
# 0         1.0          1.0         45.0       5.0                   3.0  ...
# 1         1.0          0.0         15.0       4.0                   1.0  ...
# 2         NaN          NaN         28.0       8.0                   1.0  ...
# 3         NaN          3.0         28.0       8.0                   1.0  ...
# 4         NaN          1.0         27.0       4.0                   2.0  ...
# 5         NaN          5.0         85.0      29.0                   2.0  ...
# 6         NaN          4.0         38.0      27.0                   3.0  ...
#
#      period  60 years old or more  anti-arab anti-female  \
# 0  2020, Q1                   NaN        NaN         NaN
# 1  2020, Q2                   1.0        1.0         0.0
# 2  2020, Q3                   NaN        NaN         NaN
# 3  2020, Q4                   NaN        NaN         5.0
# 4  2021, Q1                   NaN        NaN         3.0
# 5  2021, Q2                   NaN        NaN         0.0
# 6  2021, Q3                   NaN        1.0         0.0
#
#    anti-gender non-conforming  anti-hispanic  anti-lgbt  \
# 0                         NaN            NaN        NaN
# 1                         2.0            0.0        NaN
# 2                         NaN            NaN        4.0
# 3                         NaN            1.0        NaN
# 4                         NaN            1.0        1.0
# 5                         2.0            2.0        1.0
# 6                         1.0            1.0        0.0
#
#    anti-multi racial groups  anti-religious practice generally  grand total
# 0                       NaN                                NaN          NaN
# 1                       NaN                                NaN          NaN
# 2                       2.0                                2.0          NaN
# 3                       NaN                                NaN          NaN
# 4                       NaN                                NaN         96.0
# 5                       NaN                                NaN        226.0
# 6                       NaN                                NaN        114.0
#
# [7 rows x 23 columns]

# %% [markdown]
# #### Q4, 2021

# %%
df = pd.read_excel('downloaded-datasets/hate-crime-complaints-by-motivation-q4-2021.xlsx', skiprows=4)
df.dtypes
# Out:
# PRECINCT                            object
# ANTI-ASIAN                           int64
# ANTI-WHITE                           int64
# ANTI-ARAB                            int64
# ANTI-CATHOLIC                        int64
# ANTI-BLACK                           int64
# ANTI-FEMALE                          int64
# ANTI-GENDER NON CONFORMING           int64
# ANTI-FEMALE HOMOSEXUAL (LESBIAN)     int64
# ANTI-HISPANIC                        int64
# ANTI-JEWISH                          int64
# ANTI-LGBT (MIXED GROUP)              int64
# ANTI-MALE HOMOSEXUAL (GAY)           int64
# ANTI-MUSLIM                          int64
# ANTI-OTHER ETHNICITY                 int64
# ANTI-TRANSGENDER                     int64
# Grand Total                          int64
# dtype: object

# %%
df.columns = df.columns.str.lower().str.strip()
df.columns = df.columns.str.replace('\n', '')

# %%
last_row = df.tail(1)
last_row['period'] = '2021, Q4'
# Out:
# /var/folders/4f/fk_hbgy14cg47tw521m3y0xw0000gn/T/ipykernel_54677/3900099325.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_row['period'] = '2021, Q4'

# %%
last_row = last_row.rename(columns={'anti-gender non conforming': 'anti-gender non-conforming', 'anti-female homosexual (lesbian)': 'anti-lesbian', 'anti-male homosexual (gay)': 'anti-gay', 'anti-lgbt (mixed group)': 'anti-lgbt'})

# %%
common_columns = totals_df.columns.intersection(last_row.columns)
common_columns
# Out:
# Index(['precinct', 'anti-asian', 'anti-black', 'anti-catholic', 'anti-lesbian',
#        'anti-muslim', 'anti-jewish', 'anti-gay', 'anti-other ethnicity',
#        'anti-transgender', 'anti-white', 'period', 'anti-arab', 'anti-female',
#        'anti-gender non-conforming', 'anti-hispanic', 'anti-lgbt',
#        'grand total'],
#       dtype='object')

# %%
diff_columns1 = last_row.columns.difference(totals_df.columns)
diff_columns1
# Out:
# Index([], dtype='object')

# %%
totals_df = pd.concat([totals_df, last_row], ignore_index=True)
totals_df
# Out:
#       precinct  anti-asian  anti-black  anti-catholic  anti-lesbian  \
# 0        Total        11.0        12.0            1.0           1.0
# 1        Total         8.0         5.0            3.0           2.0
# 2        Total         4.0        16.0            3.0           NaN
# 3        Total         3.0         8.0            1.0           1.0
# 4  Grand Total        42.0        12.0            NaN           1.0
# 5  Grand Total        63.0        17.0            4.0           0.0
# 6  Grand Total        20.0         7.0            4.0           2.0
# 7  Grand Total        13.0         9.0            1.0           1.0
#
#    anti-hindu  anti-muslim  anti-jewish  anti-gay  anti-other ethnicity  ...  \
# 0         1.0          1.0         45.0       5.0                   3.0  ...
# 1         1.0          0.0         15.0       4.0                   1.0  ...
# 2         NaN          NaN         28.0       8.0                   1.0  ...
# 3         NaN          3.0         28.0       8.0                   1.0  ...
# 4         NaN          1.0         27.0       4.0                   2.0  ...
# 5         NaN          5.0         85.0      29.0                   2.0  ...
# 6         NaN          4.0         38.0      27.0                   3.0  ...
# 7         NaN          2.0         57.0      13.0                   3.0  ...
#
#      period  60 years old or more  anti-arab anti-female  \
# 0  2020, Q1                   NaN        NaN         NaN
# 1  2020, Q2                   1.0        1.0         0.0
# 2  2020, Q3                   NaN        NaN         NaN
# 3  2020, Q4                   NaN        NaN         5.0
# 4  2021, Q1                   NaN        NaN         3.0
# 5  2021, Q2                   NaN        NaN         0.0
# 6  2021, Q3                   NaN        1.0         0.0
# 7  2021, Q4                   NaN        0.0         0.0
#
#    anti-gender non-conforming  anti-hispanic  anti-lgbt  \
# 0                         NaN            NaN        NaN
# 1                         2.0            0.0        NaN
# 2                         NaN            NaN        4.0
# 3                         NaN            1.0        NaN
# 4                         NaN            1.0        1.0
# 5                         2.0            2.0        1.0
# 6                         1.0            1.0        0.0
# 7                         0.0            2.0        0.0
#
#    anti-multi racial groups  anti-religious practice generally  grand total
# 0                       NaN                                NaN          NaN
# 1                       NaN                                NaN          NaN
# 2                       2.0                                2.0          NaN
# 3                       NaN                                NaN          NaN
# 4                       NaN                                NaN         96.0
# 5                       NaN                                NaN        226.0
# 6                       NaN                                NaN        114.0
# 7                       NaN                                NaN        112.0
#
# [8 rows x 23 columns]

# %%
# Save as CSV for checkpoint

totals_df.to_csv('totals.csv')

# %% [markdown]
# ### Using `def` to shorten repetitive tasks
#
# At this point, I will try setting a new function through `def` to hopefully make the routine easier.

# %%
def clean(df):
    df.columns = df.columns.str.lower().str.strip()
    df.columns = df.columns.str.replace('\n', '')

# %%
# This did not work...

def merge_totals(df):
    totals_df = pd.concat([totals_df, last_row], ignore_index=True)

# %%
# This also did not work...

def common(df):
    df = df.rename(columns={'anti-other religion': 'anti-religious practice generally', 'anti-gender non conforming': 'anti-gender non-conforming', 'anti-female homosexual (lesbian)': 'anti-lesbian', 'anti-male homosexual (gay)': 'anti-gay', 'anti-lgbt (mixed group)': 'anti-lgbt'})

# %% [markdown]
# #### Q1, 2022

# %%
df = pd.read_excel('downloaded-datasets/hate-crime-complaints-by-motivation-q1-2022.xlsx', skiprows=4)
df.dtypes
# Out:
# PRECINCT                            object
# ANTI-ASIAN                           int64
# ANTI-BLACK                           int64
# ANTI-CATHOLIC                        int64
# ANTI-FEMALE HOMOSEXUAL (LESBIAN)     int64
# ANTI-HISPANIC                        int64
# ANTI-JEWISH                          int64
# ANTI-MALE HOMOSEXUAL (GAY)           int64
# ANTI-MUSLIM                          int64
# ANTI-OTHER ETHNICITY                 int64
# ANTI-OTHER RELIGION                  int64
# ANTI-TRANSGENDER                     int64
# ANTI-WHITE                           int64
# Grand Total                          int64
# dtype: object

# %%
clean(df)

# %%
df
# Out:
#        precinct  anti-asian  anti-black  anti-catholic  \
# 0           001           0           2              0
# 1           005           1           0              0
# 2           006           0           0              0
# 3           007           2           1              0
# 4           009           2           0              0
# ..          ...         ...         ...            ...
# 73          120           0           0              0
# 74          121           0           1              0
# 75          122           0           1              0
# 76          123           0           0              0
# 77  Grand Total          17          20              3
#
#     anti-female homosexual (lesbian)  anti-hispanic  anti-jewish  \
# 0                                  0              0            5
# 1                                  0              0            1
# 2                                  0              0            0
# 3                                  0              0            2
# 4                                  0              0            0
# ..                               ...            ...          ...
# 73                                 0              0            0
# 74                                 0              0            0
# 75                                 0              0            0
# 76                                 0              0            0
# 77                                 1              2           67
#
#     anti-male homosexual (gay)  anti-muslim  anti-other ethnicity  \
# 0                            0            0                     0
# 1                            0            0                     0
# 2                            0            0                     0
# 3                            0            0                     0
# 4                            1            0                     0
# ..                         ...          ...                   ...
# 73                           0            0                     0
# 74                           0            0                     0
# 75                           0            0                     0
# 76                           0            0                     0
# 77                          15            3                     7
#
#     anti-other religion  anti-transgender  anti-white  grand total
# 0                     0                 0           0            7
# 1                     0                 0           1            3
# 2                     0                 0           0            0
# 3                     0                 0           0            5
# 4                     0                 0           0            3
# ..                  ...               ...         ...          ...
# 73                    0                 0           0            0
# 74                    0                 0           0            1
# 75                    0                 0           0            1
# 76                    0                 0           0            0
# 77                    2                 4           1          142
#
# [78 rows x 14 columns]

# %%
# I can't `def` the following because the 'period' column has to be specified.

last_row = df.tail(1)
last_row['period'] = '2022, Q1'
# Out:
# /var/folders/4f/fk_hbgy14cg47tw521m3y0xw0000gn/T/ipykernel_54677/2695052722.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_row['period'] = '2022, Q1'

# %%
last_row = last_row.rename(columns={'anti-gender non conforming': 'anti-gender non-conforming', 'anti-female homosexual (lesbian)': 'anti-lesbian', 'anti-male homosexual (gay)': 'anti-gay', 'anti-lgbt (mixed group)': 'anti-lgbt'})

# %%
last_row = last_row.rename(columns={'anti-other religion': 'anti-religious practice generally'})

# %%
common_columns = totals_df.columns.intersection(last_row.columns)
common_columns
# Out:
# Index(['precinct', 'anti-asian', 'anti-black', 'anti-catholic', 'anti-lesbian',
#        'anti-muslim', 'anti-jewish', 'anti-gay', 'anti-other ethnicity',
#        'anti-transgender', 'anti-white', 'period', 'anti-hispanic',
#        'anti-religious practice generally', 'grand total'],
#       dtype='object')

# %%
diff_columns1 = last_row.columns.difference(totals_df.columns)
diff_columns1
# Out:
# Index([], dtype='object')

# %%
totals_df = pd.concat([totals_df, last_row], ignore_index=True)

# %%
totals_df
# Out:
#       precinct  anti-asian  anti-black  anti-catholic  anti-lesbian  \
# 0        Total        11.0        12.0            1.0           1.0
# 1        Total         8.0         5.0            3.0           2.0
# 2        Total         4.0        16.0            3.0           NaN
# 3        Total         3.0         8.0            1.0           1.0
# 4  Grand Total        42.0        12.0            NaN           1.0
# 5  Grand Total        63.0        17.0            4.0           0.0
# 6  Grand Total        20.0         7.0            4.0           2.0
# 7  Grand Total        13.0         9.0            1.0           1.0
# 8  Grand Total        17.0        20.0            3.0           1.0
#
#    anti-hindu  anti-muslim  anti-jewish  anti-gay  anti-other ethnicity  ...  \
# 0         1.0          1.0         45.0       5.0                   3.0  ...
# 1         1.0          0.0         15.0       4.0                   1.0  ...
# 2         NaN          NaN         28.0       8.0                   1.0  ...
# 3         NaN          3.0         28.0       8.0                   1.0  ...
# 4         NaN          1.0         27.0       4.0                   2.0  ...
# 5         NaN          5.0         85.0      29.0                   2.0  ...
# 6         NaN          4.0         38.0      27.0                   3.0  ...
# 7         NaN          2.0         57.0      13.0                   3.0  ...
# 8         NaN          3.0         67.0      15.0                   7.0  ...
#
#      period  60 years old or more  anti-arab anti-female  \
# 0  2020, Q1                   NaN        NaN         NaN
# 1  2020, Q2                   1.0        1.0         0.0
# 2  2020, Q3                   NaN        NaN         NaN
# 3  2020, Q4                   NaN        NaN         5.0
# 4  2021, Q1                   NaN        NaN         3.0
# 5  2021, Q2                   NaN        NaN         0.0
# 6  2021, Q3                   NaN        1.0         0.0
# 7  2021, Q4                   NaN        0.0         0.0
# 8  2022, Q1                   NaN        NaN         NaN
#
#    anti-gender non-conforming  anti-hispanic  anti-lgbt  \
# 0                         NaN            NaN        NaN
# 1                         2.0            0.0        NaN
# 2                         NaN            NaN        4.0
# 3                         NaN            1.0        NaN
# 4                         NaN            1.0        1.0
# 5                         2.0            2.0        1.0
# 6                         1.0            1.0        0.0
# 7                         0.0            2.0        0.0
# 8                         NaN            2.0        NaN
#
#    anti-multi racial groups  anti-religious practice generally  grand total
# 0                       NaN                                NaN          NaN
# 1                       NaN                                NaN          NaN
# 2                       2.0                                2.0          NaN
# 3                       NaN                                NaN          NaN
# 4                       NaN                                NaN         96.0
# 5                       NaN                                NaN        226.0
# 6                       NaN                                NaN        114.0
# 7                       NaN                                NaN        112.0
# 8                       NaN                                2.0        142.0
#
# [9 rows x 23 columns]

# %% [markdown]
# #### Q2, 2022

# %%
df = pd.read_excel('downloaded-datasets/hate-crime-complaints-by-motivation-q2-2022.xlsx', skiprows=4)
clean(df)
df.dtypes
# Out:
# precinct                      object
# anti-asian                     int64
# anti-black                     int64
# anti-catholic                  int64
# anti-hispanic                  int64
# anti-male homosexual (gay)     int64
# anti-muslim                    int64
# anti-other ethnicity           int64
# anti-jewish                    int64
# anti-sikh                      int64
# anti-other religion            int64
# anti-transgender               int64
# anti-white                     int64
# grand total                    int64
# dtype: object

# %%
last_row = df.tail(1)
last_row['period'] = '2022, Q2'
# Out:
# /var/folders/4f/fk_hbgy14cg47tw521m3y0xw0000gn/T/ipykernel_54677/464266979.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_row['period'] = '2022, Q2'

# %%
last_row = last_row.rename(columns={'anti-other religion': 'anti-religious practice generally', 'anti-gender non conforming': 'anti-gender non-conforming', 'anti-female homosexual (lesbian)': 'anti-lesbian', 'anti-male homosexual (gay)': 'anti-gay', 'anti-lgbt (mixed group)': 'anti-lgbt'})

# %%
common_columns = totals_df.columns.intersection(last_row.columns)
common_columns
# Out:
# Index(['precinct', 'anti-asian', 'anti-black', 'anti-catholic', 'anti-muslim',
#        'anti-jewish', 'anti-gay', 'anti-other ethnicity', 'anti-transgender',
#        'anti-white', 'period', 'anti-hispanic',
#        'anti-religious practice generally', 'grand total'],
#       dtype='object')

# %%
diff_columns1 = last_row.columns.difference(totals_df.columns)
diff_columns1
# Out:
# Index(['anti-sikh'], dtype='object')

# %%
totals_df = pd.concat([totals_df, last_row], ignore_index=True)
totals_df
# Out:
#       precinct  anti-asian  anti-black  anti-catholic  anti-lesbian  \
# 0        Total        11.0        12.0            1.0           1.0
# 1        Total         8.0         5.0            3.0           2.0
# 2        Total         4.0        16.0            3.0           NaN
# 3        Total         3.0         8.0            1.0           1.0
# 4  Grand Total        42.0        12.0            NaN           1.0
# 5  Grand Total        63.0        17.0            4.0           0.0
# 6  Grand Total        20.0         7.0            4.0           2.0
# 7  Grand Total        13.0         9.0            1.0           1.0
# 8  Grand Total        17.0        20.0            3.0           1.0
# 9  Grand Total        20.0        11.0            3.0           NaN
#
#    anti-hindu  anti-muslim  anti-jewish  anti-gay  anti-other ethnicity  ...  \
# 0         1.0          1.0         45.0       5.0                   3.0  ...
# 1         1.0          0.0         15.0       4.0                   1.0  ...
# 2         NaN          NaN         28.0       8.0                   1.0  ...
# 3         NaN          3.0         28.0       8.0                   1.0  ...
# 4         NaN          1.0         27.0       4.0                   2.0  ...
# 5         NaN          5.0         85.0      29.0                   2.0  ...
# 6         NaN          4.0         38.0      27.0                   3.0  ...
# 7         NaN          2.0         57.0      13.0                   3.0  ...
# 8         NaN          3.0         67.0      15.0                   7.0  ...
# 9         NaN         14.0         64.0      24.0                   9.0  ...
#
#    60 years old or more  anti-arab  anti-female anti-gender non-conforming  \
# 0                   NaN        NaN          NaN                        NaN
# 1                   1.0        1.0          0.0                        2.0
# 2                   NaN        NaN          NaN                        NaN
# 3                   NaN        NaN          5.0                        NaN
# 4                   NaN        NaN          3.0                        NaN
# 5                   NaN        NaN          0.0                        2.0
# 6                   NaN        1.0          0.0                        1.0
# 7                   NaN        0.0          0.0                        0.0
# 8                   NaN        NaN          NaN                        NaN
# 9                   NaN        NaN          NaN                        NaN
#
#    anti-hispanic  anti-lgbt  anti-multi racial groups  \
# 0            NaN        NaN                       NaN
# 1            0.0        NaN                       NaN
# 2            NaN        4.0                       2.0
# 3            1.0        NaN                       NaN
# 4            1.0        1.0                       NaN
# 5            2.0        1.0                       NaN
# 6            1.0        0.0                       NaN
# 7            2.0        0.0                       NaN
# 8            2.0        NaN                       NaN
# 9            6.0        NaN                       NaN
#
#    anti-religious practice generally  grand total  anti-sikh
# 0                                NaN          NaN        NaN
# 1                                NaN          NaN        NaN
# 2                                2.0          NaN        NaN
# 3                                NaN          NaN        NaN
# 4                                NaN         96.0        NaN
# 5                                NaN        226.0        NaN
# 6                                NaN        114.0        NaN
# 7                                NaN        112.0        NaN
# 8                                2.0        142.0        NaN
# 9                                0.0        155.0        2.0
#
# [10 rows x 24 columns]

# %% [markdown]
# #### Q3, 2022
#
# Observed issue: The filename was misspelled.

# %%
df = pd.read_excel('downloaded-datasets/hate-crime-complaints-by-motiviation-q3-2022.xlsx', skiprows=4)
clean(df)
df.dtypes
# Out:
# precinct                            object
# anti-asian                           int64
# anti-black                           int64
# anti-eastern orthodox                int64
# anti-female homosexual (lesbian)     int64
# anti-hindu                           int64
# anti-hispanic                        int64
# anti-jehovahs witness                int64
# anti-jewish                          int64
# anti-male homosexual (gay)           int64
# anti-other ethnicity                 int64
# anti-transgender                     int64
# anti-white                           int64
# grand total                          int64
# dtype: object

# %%
last_row = df.tail(1)
last_row['period'] = '2022, Q3'
# Out:
# /var/folders/4f/fk_hbgy14cg47tw521m3y0xw0000gn/T/ipykernel_54677/1564026510.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_row['period'] = '2022, Q3'

# %%
last_row = last_row.rename(columns={'anti-other religion': 'anti-religious practice generally', 'anti-gender non conforming': 'anti-gender non-conforming', 'anti-female homosexual (lesbian)': 'anti-lesbian', 'anti-male homosexual (gay)': 'anti-gay', 'anti-lgbt (mixed group)': 'anti-lgbt'})

# %%
diff_columns1 = last_row.columns.difference(totals_df.columns)
diff_columns1
# Out:
# Index(['anti-eastern orthodox', 'anti-jehovahs witness'], dtype='object')

# %%
common_columns = totals_df.columns.intersection(last_row.columns)
common_columns
# Out:
# Index(['precinct', 'anti-asian', 'anti-black', 'anti-lesbian', 'anti-hindu',
#        'anti-jewish', 'anti-gay', 'anti-other ethnicity', 'anti-transgender',
#        'anti-white', 'period', 'anti-hispanic', 'grand total'],
#       dtype='object')

# %%
totals_df = pd.concat([totals_df, last_row], ignore_index=True)
totals_df
# Out:
#        precinct  anti-asian  anti-black  anti-catholic  anti-lesbian  \
# 0         Total        11.0        12.0            1.0           1.0
# 1         Total         8.0         5.0            3.0           2.0
# 2         Total         4.0        16.0            3.0           NaN
# 3         Total         3.0         8.0            1.0           1.0
# 4   Grand Total        42.0        12.0            NaN           1.0
# 5   Grand Total        63.0        17.0            4.0           0.0
# 6   Grand Total        20.0         7.0            4.0           2.0
# 7   Grand Total        13.0         9.0            1.0           1.0
# 8   Grand Total        17.0        20.0            3.0           1.0
# 9   Grand Total        20.0        11.0            3.0           NaN
# 10  Grand Total        21.0        11.0            NaN           5.0
#
#     anti-hindu  anti-muslim  anti-jewish  anti-gay  anti-other ethnicity  ...  \
# 0          1.0          1.0         45.0       5.0                   3.0  ...
# 1          1.0          0.0         15.0       4.0                   1.0  ...
# 2          NaN          NaN         28.0       8.0                   1.0  ...
# 3          NaN          3.0         28.0       8.0                   1.0  ...
# 4          NaN          1.0         27.0       4.0                   2.0  ...
# 5          NaN          5.0         85.0      29.0                   2.0  ...
# 6          NaN          4.0         38.0      27.0                   3.0  ...
# 7          NaN          2.0         57.0      13.0                   3.0  ...
# 8          NaN          3.0         67.0      15.0                   7.0  ...
# 9          NaN         14.0         64.0      24.0                   9.0  ...
# 10         3.0          NaN         47.0      18.0                  14.0  ...
#
#     anti-female  anti-gender non-conforming  anti-hispanic anti-lgbt  \
# 0           NaN                         NaN            NaN       NaN
# 1           0.0                         2.0            0.0       NaN
# 2           NaN                         NaN            NaN       4.0
# 3           5.0                         NaN            1.0       NaN
# 4           3.0                         NaN            1.0       1.0
# 5           0.0                         2.0            2.0       1.0
# 6           0.0                         1.0            1.0       0.0
# 7           0.0                         0.0            2.0       0.0
# 8           NaN                         NaN            2.0       NaN
# 9           NaN                         NaN            6.0       NaN
# 10          NaN                         NaN            1.0       NaN
#
#     anti-multi racial groups  anti-religious practice generally  grand total  \
# 0                        NaN                                NaN          NaN
# 1                        NaN                                NaN          NaN
# 2                        2.0                                2.0          NaN
# 3                        NaN                                NaN          NaN
# 4                        NaN                                NaN         96.0
# 5                        NaN                                NaN        226.0
# 6                        NaN                                NaN        114.0
# 7                        NaN                                NaN        112.0
# 8                        NaN                                2.0        142.0
# 9                        NaN                                0.0        155.0
# 10                       NaN                                NaN        131.0
#
#     anti-sikh  anti-eastern orthodox  anti-jehovahs witness
# 0         NaN                    NaN                    NaN
# 1         NaN                    NaN                    NaN
# 2         NaN                    NaN                    NaN
# 3         NaN                    NaN                    NaN
# 4         NaN                    NaN                    NaN
# 5         NaN                    NaN                    NaN
# 6         NaN                    NaN                    NaN
# 7         NaN                    NaN                    NaN
# 8         NaN                    NaN                    NaN
# 9         2.0                    NaN                    NaN
# 10        NaN                    2.0                    1.0
#
# [11 rows x 26 columns]

# %% [markdown]
# #### Q4, 2022

# %%
df = pd.read_excel('downloaded-datasets/hate-crime-complaints-by-motivation-q4-2022.xlsx', skiprows=4)
clean(df)
df.dtypes
# Out:
# precinct                             object
# anti-asian                            int64
# anti-black                            int64
# anti-buddhist                         int64
# anti-catholic                         int64
# anti-female homosexual (lesbian)      int64
# anti-hispanic                         int64
# anti-jewish                           int64
# anti-male homosexual (gay)            int64
# anti-other ethnicity                  int64
# anti-protestant                       int64
# anti-religious practice generally     int64
# anti-transgender                      int64
# anti-white                            int64
# grand total                           int64
# dtype: object

# %%
last_row = df.tail(1)
last_row['period'] = '2022, Q4'
# Out:
# /var/folders/4f/fk_hbgy14cg47tw521m3y0xw0000gn/T/ipykernel_54677/3543889445.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_row['period'] = '2022, Q4'

# %%
last_row = last_row.rename(columns={'anti-other religion': 'anti-religious practice generally', 'anti-gender non conforming': 'anti-gender non-conforming', 'anti-female homosexual (lesbian)': 'anti-lesbian', 'anti-male homosexual (gay)': 'anti-gay', 'anti-lgbt (mixed group)': 'anti-lgbt'})

# %%
common_columns = totals_df.columns.intersection(last_row.columns)
common_columns
# Out:
# Index(['precinct', 'anti-asian', 'anti-black', 'anti-catholic', 'anti-lesbian',
#        'anti-jewish', 'anti-gay', 'anti-other ethnicity', 'anti-transgender',
#        'anti-white', 'period', 'anti-hispanic',
#        'anti-religious practice generally', 'grand total'],
#       dtype='object')

# %%
diff_columns1 = last_row.columns.difference(totals_df.columns)
diff_columns1
# Out:
# Index(['anti-buddhist', 'anti-protestant'], dtype='object')

# %%
totals_df = pd.concat([totals_df, last_row], ignore_index=True)
totals_df
# Out:
#        precinct  anti-asian  anti-black  anti-catholic  anti-lesbian  \
# 0         Total        11.0        12.0            1.0           1.0
# 1         Total         8.0         5.0            3.0           2.0
# 2         Total         4.0        16.0            3.0           NaN
# 3         Total         3.0         8.0            1.0           1.0
# 4   Grand Total        42.0        12.0            NaN           1.0
# 5   Grand Total        63.0        17.0            4.0           0.0
# 6   Grand Total        20.0         7.0            4.0           2.0
# 7   Grand Total        13.0         9.0            1.0           1.0
# 8   Grand Total        17.0        20.0            3.0           1.0
# 9   Grand Total        20.0        11.0            3.0           NaN
# 10  Grand Total        21.0        11.0            NaN           5.0
# 11  Grand Total         5.0         7.0            6.0           1.0
#
#     anti-hindu  anti-muslim  anti-jewish  anti-gay  anti-other ethnicity  ...  \
# 0          1.0          1.0         45.0       5.0                   3.0  ...
# 1          1.0          0.0         15.0       4.0                   1.0  ...
# 2          NaN          NaN         28.0       8.0                   1.0  ...
# 3          NaN          3.0         28.0       8.0                   1.0  ...
# 4          NaN          1.0         27.0       4.0                   2.0  ...
# 5          NaN          5.0         85.0      29.0                   2.0  ...
# 6          NaN          4.0         38.0      27.0                   3.0  ...
# 7          NaN          2.0         57.0      13.0                   3.0  ...
# 8          NaN          3.0         67.0      15.0                   7.0  ...
# 9          NaN         14.0         64.0      24.0                   9.0  ...
# 10         3.0          NaN         47.0      18.0                  14.0  ...
# 11         NaN          NaN         59.0       6.0                   8.0  ...
#
#     anti-hispanic  anti-lgbt  anti-multi racial groups  \
# 0             NaN        NaN                       NaN
# 1             0.0        NaN                       NaN
# 2             NaN        4.0                       2.0
# 3             1.0        NaN                       NaN
# 4             1.0        1.0                       NaN
# 5             2.0        1.0                       NaN
# 6             1.0        0.0                       NaN
# 7             2.0        0.0                       NaN
# 8             2.0        NaN                       NaN
# 9             6.0        NaN                       NaN
# 10            1.0        NaN                       NaN
# 11            5.0        NaN                       NaN
#
#    anti-religious practice generally  grand total  anti-sikh  \
# 0                                NaN          NaN        NaN
# 1                                NaN          NaN        NaN
# 2                                2.0          NaN        NaN
# 3                                NaN          NaN        NaN
# 4                                NaN         96.0        NaN
# 5                                NaN        226.0        NaN
# 6                                NaN        114.0        NaN
# 7                                NaN        112.0        NaN
# 8                                2.0        142.0        NaN
# 9                                0.0        155.0        2.0
# 10                               NaN        131.0        NaN
# 11                               1.0        107.0        NaN
#
#     anti-eastern orthodox  anti-jehovahs witness  anti-buddhist  \
# 0                     NaN                    NaN            NaN
# 1                     NaN                    NaN            NaN
# 2                     NaN                    NaN            NaN
# 3                     NaN                    NaN            NaN
# 4                     NaN                    NaN            NaN
# 5                     NaN                    NaN            NaN
# 6                     NaN                    NaN            NaN
# 7                     NaN                    NaN            NaN
# 8                     NaN                    NaN            NaN
# 9                     NaN                    NaN            NaN
# 10                    2.0                    1.0            NaN
# 11                    NaN                    NaN            1.0
#
#     anti-protestant
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              1.0
#
# [12 rows x 28 columns]

# %% [markdown]
# #### Q1, 2023

# %%
df = pd.read_excel('downloaded-datasets/hate-crime-complaints-by-motivation-q1-2023.xlsx', skiprows=4)
clean(df)
df.dtypes
# Out:
# precinct                            object
# anti-asian                           int64
# anti-black                           int64
# anti-catholic                        int64
# anti-female homosexual (lesbian)     int64
# anti-gender non conforming           int64
# anti-hispanic                        int64
# anti-jehovahs witness                int64
# anti-jewish                          int64
# anti-male homosexual (gay)           int64
# anti-muslim                          int64
# anti-other ethnicity                 int64
# anti-transgender                     int64
# anti-white                           int64
# grand total                          int64
# dtype: object

# %%
last_row = df.tail(1)
last_row['period'] = '2023, Q1'
# Out:
# /var/folders/4f/fk_hbgy14cg47tw521m3y0xw0000gn/T/ipykernel_54677/493172275.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_row['period'] = '2023, Q1'

# %%
last_row = last_row.rename(columns={'anti-other religion': 'anti-religious practice generally', 'anti-gender non conforming': 'anti-gender non-conforming', 'anti-female homosexual (lesbian)': 'anti-lesbian', 'anti-male homosexual (gay)': 'anti-gay', 'anti-lgbt (mixed group)': 'anti-lgbt'})

# %%
common_columns = totals_df.columns.intersection(last_row.columns)
common_columns
# Out:
# Index(['precinct', 'anti-asian', 'anti-black', 'anti-catholic', 'anti-lesbian',
#        'anti-muslim', 'anti-jewish', 'anti-gay', 'anti-other ethnicity',
#        'anti-transgender', 'anti-white', 'period',
#        'anti-gender non-conforming', 'anti-hispanic', 'grand total',
#        'anti-jehovahs witness'],
#       dtype='object')

# %%
diff_columns1 = last_row.columns.difference(totals_df.columns)
diff_columns1
# Out:
# Index([], dtype='object')

# %%
totals_df = pd.concat([totals_df, last_row], ignore_index=True)
totals_df
# Out:
#        precinct  anti-asian  anti-black  anti-catholic  anti-lesbian  \
# 0         Total        11.0        12.0            1.0           1.0
# 1         Total         8.0         5.0            3.0           2.0
# 2         Total         4.0        16.0            3.0           NaN
# 3         Total         3.0         8.0            1.0           1.0
# 4   Grand Total        42.0        12.0            NaN           1.0
# 5   Grand Total        63.0        17.0            4.0           0.0
# 6   Grand Total        20.0         7.0            4.0           2.0
# 7   Grand Total        13.0         9.0            1.0           1.0
# 8   Grand Total        17.0        20.0            3.0           1.0
# 9   Grand Total        20.0        11.0            3.0           NaN
# 10  Grand Total        21.0        11.0            NaN           5.0
# 11  Grand Total         5.0         7.0            6.0           1.0
# 12  Grand Total         6.0        10.0            4.0           2.0
#
#     anti-hindu  anti-muslim  anti-jewish  anti-gay  anti-other ethnicity  ...  \
# 0          1.0          1.0         45.0       5.0                   3.0  ...
# 1          1.0          0.0         15.0       4.0                   1.0  ...
# 2          NaN          NaN         28.0       8.0                   1.0  ...
# 3          NaN          3.0         28.0       8.0                   1.0  ...
# 4          NaN          1.0         27.0       4.0                   2.0  ...
# 5          NaN          5.0         85.0      29.0                   2.0  ...
# 6          NaN          4.0         38.0      27.0                   3.0  ...
# 7          NaN          2.0         57.0      13.0                   3.0  ...
# 8          NaN          3.0         67.0      15.0                   7.0  ...
# 9          NaN         14.0         64.0      24.0                   9.0  ...
# 10         3.0          NaN         47.0      18.0                  14.0  ...
# 11         NaN          NaN         59.0       6.0                   8.0  ...
# 12         NaN          1.0         60.0      11.0                   4.0  ...
#
#     anti-hispanic  anti-lgbt  anti-multi racial groups  \
# 0             NaN        NaN                       NaN
# 1             0.0        NaN                       NaN
# 2             NaN        4.0                       2.0
# 3             1.0        NaN                       NaN
# 4             1.0        1.0                       NaN
# 5             2.0        1.0                       NaN
# 6             1.0        0.0                       NaN
# 7             2.0        0.0                       NaN
# 8             2.0        NaN                       NaN
# 9             6.0        NaN                       NaN
# 10            1.0        NaN                       NaN
# 11            5.0        NaN                       NaN
# 12            1.0        NaN                       NaN
#
#    anti-religious practice generally  grand total  anti-sikh  \
# 0                                NaN          NaN        NaN
# 1                                NaN          NaN        NaN
# 2                                2.0          NaN        NaN
# 3                                NaN          NaN        NaN
# 4                                NaN         96.0        NaN
# 5                                NaN        226.0        NaN
# 6                                NaN        114.0        NaN
# 7                                NaN        112.0        NaN
# 8                                2.0        142.0        NaN
# 9                                0.0        155.0        2.0
# 10                               NaN        131.0        NaN
# 11                               1.0        107.0        NaN
# 12                               NaN        111.0        NaN
#
#     anti-eastern orthodox  anti-jehovahs witness  anti-buddhist  \
# 0                     NaN                    NaN            NaN
# 1                     NaN                    NaN            NaN
# 2                     NaN                    NaN            NaN
# 3                     NaN                    NaN            NaN
# 4                     NaN                    NaN            NaN
# 5                     NaN                    NaN            NaN
# 6                     NaN                    NaN            NaN
# 7                     NaN                    NaN            NaN
# 8                     NaN                    NaN            NaN
# 9                     NaN                    NaN            NaN
# 10                    2.0                    1.0            NaN
# 11                    NaN                    NaN            1.0
# 12                    NaN                    1.0            NaN
#
#     anti-protestant
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              1.0
# 12              NaN
#
# [13 rows x 28 columns]

# %% [markdown]
# #### Q2, 2023

# %%
df = pd.read_excel('downloaded-datasets/hate-crime-complaints-by-motivation-q2-2023.xlsx', skiprows=4)
clean(df)
df.dtypes
# Out:
# precinct                            object
# anti-asian                           int64
# anti-black                           int64
# anti-catholic                        int64
# anti-female homosexual (lesbian)     int64
# anti-gender non conforming           int64
# anti-hispanic                        int64
# anti-jewish                          int64
# anti-male homosexual (gay)           int64
# anti-muslim                          int64
# anti-other ethnicity                 int64
# anti-transgender                     int64
# anti-white                           int64
# grand total                          int64
# dtype: object

# %%
last_row = df.tail(1)
last_row['period'] = '2023, Q2'
# Out:
# /var/folders/4f/fk_hbgy14cg47tw521m3y0xw0000gn/T/ipykernel_54677/4265884935.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_row['period'] = '2023, Q2'

# %%
last_row = last_row.rename(columns={'anti-other religion': 'anti-religious practice generally', 'anti-gender non conforming': 'anti-gender non-conforming', 'anti-female homosexual (lesbian)': 'anti-lesbian', 'anti-male homosexual (gay)': 'anti-gay', 'anti-lgbt (mixed group)': 'anti-lgbt'})

# %%
diff_columns1 = last_row.columns.difference(totals_df.columns)
diff_columns1
# Out:
# Index([], dtype='object')

# %%
totals_df = pd.concat([totals_df, last_row], ignore_index=True)
totals_df
# Out:
#        precinct  anti-asian  anti-black  anti-catholic  anti-lesbian  \
# 0         Total        11.0        12.0            1.0           1.0
# 1         Total         8.0         5.0            3.0           2.0
# 2         Total         4.0        16.0            3.0           NaN
# 3         Total         3.0         8.0            1.0           1.0
# 4   Grand Total        42.0        12.0            NaN           1.0
# 5   Grand Total        63.0        17.0            4.0           0.0
# 6   Grand Total        20.0         7.0            4.0           2.0
# 7   Grand Total        13.0         9.0            1.0           1.0
# 8   Grand Total        17.0        20.0            3.0           1.0
# 9   Grand Total        20.0        11.0            3.0           NaN
# 10  Grand Total        21.0        11.0            NaN           5.0
# 11  Grand Total         5.0         7.0            6.0           1.0
# 12  Grand Total         6.0        10.0            4.0           2.0
# 13  Grand Total        13.0        10.0            1.0           1.0
#
#     anti-hindu  anti-muslim  anti-jewish  anti-gay  anti-other ethnicity  ...  \
# 0          1.0          1.0         45.0       5.0                   3.0  ...
# 1          1.0          0.0         15.0       4.0                   1.0  ...
# 2          NaN          NaN         28.0       8.0                   1.0  ...
# 3          NaN          3.0         28.0       8.0                   1.0  ...
# 4          NaN          1.0         27.0       4.0                   2.0  ...
# 5          NaN          5.0         85.0      29.0                   2.0  ...
# 6          NaN          4.0         38.0      27.0                   3.0  ...
# 7          NaN          2.0         57.0      13.0                   3.0  ...
# 8          NaN          3.0         67.0      15.0                   7.0  ...
# 9          NaN         14.0         64.0      24.0                   9.0  ...
# 10         3.0          NaN         47.0      18.0                  14.0  ...
# 11         NaN          NaN         59.0       6.0                   8.0  ...
# 12         NaN          1.0         60.0      11.0                   4.0  ...
# 13         NaN          5.0         48.0      19.0                   8.0  ...
#
#     anti-hispanic  anti-lgbt  anti-multi racial groups  \
# 0             NaN        NaN                       NaN
# 1             0.0        NaN                       NaN
# 2             NaN        4.0                       2.0
# 3             1.0        NaN                       NaN
# 4             1.0        1.0                       NaN
# 5             2.0        1.0                       NaN
# 6             1.0        0.0                       NaN
# 7             2.0        0.0                       NaN
# 8             2.0        NaN                       NaN
# 9             6.0        NaN                       NaN
# 10            1.0        NaN                       NaN
# 11            5.0        NaN                       NaN
# 12            1.0        NaN                       NaN
# 13            4.0        NaN                       NaN
#
#    anti-religious practice generally  grand total  anti-sikh  \
# 0                                NaN          NaN        NaN
# 1                                NaN          NaN        NaN
# 2                                2.0          NaN        NaN
# 3                                NaN          NaN        NaN
# 4                                NaN         96.0        NaN
# 5                                NaN        226.0        NaN
# 6                                NaN        114.0        NaN
# 7                                NaN        112.0        NaN
# 8                                2.0        142.0        NaN
# 9                                0.0        155.0        2.0
# 10                               NaN        131.0        NaN
# 11                               1.0        107.0        NaN
# 12                               NaN        111.0        NaN
# 13                               NaN        120.0        NaN
#
#     anti-eastern orthodox  anti-jehovahs witness  anti-buddhist  \
# 0                     NaN                    NaN            NaN
# 1                     NaN                    NaN            NaN
# 2                     NaN                    NaN            NaN
# 3                     NaN                    NaN            NaN
# 4                     NaN                    NaN            NaN
# 5                     NaN                    NaN            NaN
# 6                     NaN                    NaN            NaN
# 7                     NaN                    NaN            NaN
# 8                     NaN                    NaN            NaN
# 9                     NaN                    NaN            NaN
# 10                    2.0                    1.0            NaN
# 11                    NaN                    NaN            1.0
# 12                    NaN                    1.0            NaN
# 13                    NaN                    NaN            NaN
#
#     anti-protestant
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              1.0
# 12              NaN
# 13              NaN
#
# [14 rows x 28 columns]

# %% [markdown]
# #### Q3, 2023

# %%
df = pd.read_excel('downloaded-datasets/hate-crime-complaints-by-motivation-q3-2023.xlsx', skiprows=4)
clean(df)
df.dtypes
# Out:
# precinct                            object
# anti-asian                           int64
# anti-black                           int64
# anti-catholic                        int64
# anti-female homosexual (lesbian)     int64
# anti-hispanic                        int64
# anti-jewish                          int64
# anti-male homosexual (gay)           int64
# anti-muslim                          int64
# anti-other ethnicity                 int64
# anti-protestant                      int64
# anti-transgender                     int64
# anti-white                           int64
# grand total                          int64
# dtype: object

# %%
last_row = df.tail(1)
last_row['period'] = '2023, Q3'
# Out:
# /var/folders/4f/fk_hbgy14cg47tw521m3y0xw0000gn/T/ipykernel_54677/4244797752.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_row['period'] = '2023, Q3'

# %%
last_row = last_row.rename(columns={'anti-other religion': 'anti-religious practice generally', 'anti-gender non conforming': 'anti-gender non-conforming', 'anti-female homosexual (lesbian)': 'anti-lesbian', 'anti-male homosexual (gay)': 'anti-gay', 'anti-lgbt (mixed group)': 'anti-lgbt'})

# %%
diff_columns1 = last_row.columns.difference(totals_df.columns)
diff_columns1
# Out:
# Index([], dtype='object')

# %%
totals_df = pd.concat([totals_df, last_row], ignore_index=True)
totals_df
# Out:
#        precinct  anti-asian  anti-black  anti-catholic  anti-lesbian  \
# 0         Total        11.0        12.0            1.0           1.0
# 1         Total         8.0         5.0            3.0           2.0
# 2         Total         4.0        16.0            3.0           NaN
# 3         Total         3.0         8.0            1.0           1.0
# 4   Grand Total        42.0        12.0            NaN           1.0
# 5   Grand Total        63.0        17.0            4.0           0.0
# 6   Grand Total        20.0         7.0            4.0           2.0
# 7   Grand Total        13.0         9.0            1.0           1.0
# 8   Grand Total        17.0        20.0            3.0           1.0
# 9   Grand Total        20.0        11.0            3.0           NaN
# 10  Grand Total        21.0        11.0            NaN           5.0
# 11  Grand Total         5.0         7.0            6.0           1.0
# 12  Grand Total         6.0        10.0            4.0           2.0
# 13  Grand Total        13.0        10.0            1.0           1.0
# 14  Grand Total        12.0        13.0            1.0           2.0
#
#     anti-hindu  anti-muslim  anti-jewish  anti-gay  anti-other ethnicity  ...  \
# 0          1.0          1.0         45.0       5.0                   3.0  ...
# 1          1.0          0.0         15.0       4.0                   1.0  ...
# 2          NaN          NaN         28.0       8.0                   1.0  ...
# 3          NaN          3.0         28.0       8.0                   1.0  ...
# 4          NaN          1.0         27.0       4.0                   2.0  ...
# 5          NaN          5.0         85.0      29.0                   2.0  ...
# 6          NaN          4.0         38.0      27.0                   3.0  ...
# 7          NaN          2.0         57.0      13.0                   3.0  ...
# 8          NaN          3.0         67.0      15.0                   7.0  ...
# 9          NaN         14.0         64.0      24.0                   9.0  ...
# 10         3.0          NaN         47.0      18.0                  14.0  ...
# 11         NaN          NaN         59.0       6.0                   8.0  ...
# 12         NaN          1.0         60.0      11.0                   4.0  ...
# 13         NaN          5.0         48.0      19.0                   8.0  ...
# 14         NaN          2.0         38.0      22.0                   3.0  ...
#
#     anti-hispanic  anti-lgbt  anti-multi racial groups  \
# 0             NaN        NaN                       NaN
# 1             0.0        NaN                       NaN
# 2             NaN        4.0                       2.0
# 3             1.0        NaN                       NaN
# 4             1.0        1.0                       NaN
# 5             2.0        1.0                       NaN
# 6             1.0        0.0                       NaN
# 7             2.0        0.0                       NaN
# 8             2.0        NaN                       NaN
# 9             6.0        NaN                       NaN
# 10            1.0        NaN                       NaN
# 11            5.0        NaN                       NaN
# 12            1.0        NaN                       NaN
# 13            4.0        NaN                       NaN
# 14            4.0        NaN                       NaN
#
#    anti-religious practice generally  grand total  anti-sikh  \
# 0                                NaN          NaN        NaN
# 1                                NaN          NaN        NaN
# 2                                2.0          NaN        NaN
# 3                                NaN          NaN        NaN
# 4                                NaN         96.0        NaN
# 5                                NaN        226.0        NaN
# 6                                NaN        114.0        NaN
# 7                                NaN        112.0        NaN
# 8                                2.0        142.0        NaN
# 9                                0.0        155.0        2.0
# 10                               NaN        131.0        NaN
# 11                               1.0        107.0        NaN
# 12                               NaN        111.0        NaN
# 13                               NaN        120.0        NaN
# 14                               NaN        106.0        NaN
#
#     anti-eastern orthodox  anti-jehovahs witness  anti-buddhist  \
# 0                     NaN                    NaN            NaN
# 1                     NaN                    NaN            NaN
# 2                     NaN                    NaN            NaN
# 3                     NaN                    NaN            NaN
# 4                     NaN                    NaN            NaN
# 5                     NaN                    NaN            NaN
# 6                     NaN                    NaN            NaN
# 7                     NaN                    NaN            NaN
# 8                     NaN                    NaN            NaN
# 9                     NaN                    NaN            NaN
# 10                    2.0                    1.0            NaN
# 11                    NaN                    NaN            1.0
# 12                    NaN                    1.0            NaN
# 13                    NaN                    NaN            NaN
# 14                    NaN                    NaN            NaN
#
#     anti-protestant
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              1.0
# 12              NaN
# 13              NaN
# 14              1.0
#
# [15 rows x 28 columns]

# %% [markdown]
# #### Q4, 2023

# %%
df = pd.read_excel('downloaded-datasets/hate-crime-complaints-by-motivation-q4-2023.xlsx', skiprows=4)
clean(df)
df.dtypes
# Out:
# precinct                            object
# anti-asian                           int64
# anti-black                           int64
# anti-buddhist                        int64
# anti-catholic                        int64
# anti-female homosexual (lesbian)     int64
# anti-gender non conforming           int64
# anti-hispanic                        int64
# anti-jewish                          int64
# anti-male homosexual (gay)           int64
# anti-muslim                          int64
# anti-other ethnicity                 int64
# anti-sikh                            int64
# anti-transgender                     int64
# anti-white                           int64
# grand total                          int64
# dtype: object

# %%
last_row = df.tail(1)
last_row['period'] = '2023, Q4'
# Out:
# /var/folders/4f/fk_hbgy14cg47tw521m3y0xw0000gn/T/ipykernel_54677/2130269765.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_row['period'] = '2023, Q4'

# %%
last_row = last_row.rename(columns={'anti-other religion': 'anti-religious practice generally', 'anti-gender non conforming': 'anti-gender non-conforming', 'anti-female homosexual (lesbian)': 'anti-lesbian', 'anti-male homosexual (gay)': 'anti-gay', 'anti-lgbt (mixed group)': 'anti-lgbt'})

# %%
diff_columns1 = last_row.columns.difference(totals_df.columns)
diff_columns1
# Out:
# Index([], dtype='object')

# %%
totals_df = pd.concat([totals_df, last_row], ignore_index=True)
totals_df['period']
# Out:
# 0     2020, Q1
# 1     2020, Q2
# 2     2020, Q3
# 3     2020, Q4
# 4     2021, Q1
# 5     2021, Q2
# 6     2021, Q3
# 7     2021, Q4
# 8     2022, Q1
# 9     2022, Q2
# 10    2022, Q3
# 11    2022, Q4
# 12    2023, Q1
# 13    2023, Q2
# 14    2023, Q3
# 15    2023, Q4
# Name: period, dtype: object

# %% [markdown]
# #### Q1, 2024
#
# Finally, we're here!

# %%
df = pd.read_excel('downloaded-datasets/hate-crime-complaints-by-motivation-q1-2024.xlsx', skiprows=4)
clean(df)
df.dtypes
# Out:
# precinct                            object
# anti-asian                           int64
# anti-black                           int64
# anti-buddhist                        int64
# anti-catholic                        int64
# anti-female homosexual (lesbian)     int64
# anti-gender non conforming           int64
# anti-hispanic                        int64
# anti-jewish                          int64
# anti-male homosexual (gay)           int64
# anti-muslim                          int64
# anti-other ethnicity                 int64
# anti-protestant                      int64
# anti-sikh                            int64
# anti-transgender                     int64
# anti-white                           int64
# grand total                          int64
# dtype: object

# %%
last_row = df.tail(1)
last_row['period'] = '2024, Q1'
# Out:
# /var/folders/4f/fk_hbgy14cg47tw521m3y0xw0000gn/T/ipykernel_54677/704503961.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_row['period'] = '2024, Q1'

# %%
last_row = last_row.rename(columns={'anti-other religion': 'anti-religious practice generally', 'anti-gender non conforming': 'anti-gender non-conforming', 'anti-female homosexual (lesbian)': 'anti-lesbian', 'anti-male homosexual (gay)': 'anti-gay', 'anti-lgbt (mixed group)': 'anti-lgbt'})

# %%
diff_columns1 = last_row.columns.difference(totals_df.columns)
diff_columns1
# Out:
# Index([], dtype='object')

# %%
totals_df = pd.concat([totals_df, last_row], ignore_index=True)
totals_df['period']
# Out:
# 0     2020, Q1
# 1     2020, Q2
# 2     2020, Q3
# 3     2020, Q4
# 4     2021, Q1
# 5     2021, Q2
# 6     2021, Q3
# 7     2021, Q4
# 8     2022, Q1
# 9     2022, Q2
# 10    2022, Q3
# 11    2022, Q4
# 12    2023, Q1
# 13    2023, Q2
# 14    2023, Q3
# 15    2023, Q4
# 16    2024, Q1
# Name: period, dtype: object

# %%
# Final checkpoint!

totals_df.to_csv('totals.csv')

# %% [markdown]
# ## Now, the magic happens! ✨
#
# ***Sort of...*** First, I'll check if my columns are in order.

# %%
# Removing the 'precinct' column, which was totally unnecessary...

totals_df.drop(columns=['precinct'], inplace=True)

# %%
# Note: This shows totals per quarter.

totals_df['total'].combine_first(totals_df['grand total'])
# Out:
# 0      84.0
# 1      46.0
# 2      75.0
# 3      60.0
# 4      96.0
# 5     226.0
# 6     114.0
# 7     112.0
# 8     142.0
# 9     155.0
# 10    131.0
# 11    107.0
# 12    111.0
# 13    120.0
# 14    106.0
# 15    257.0
# 16    136.0
# Name: total, dtype: float64

# %%
totals_df['total'] = totals_df['total'].combine_first(totals_df['grand total'])

# %%
totals_df.drop(columns=['grand total'], inplace=True)

# %% [markdown]
# ## Magic 2.0! ✨
#
# Not yet, but we're getting there. The `total` column shows the total number of hate crime complaints reported per quarter. I also want to check the total number of hate crime complaints per "bias motivation".
#
# Then, I can do all the data analyses and viz that I want. Probably.

# %%
# Sum per column

totals_df.loc['Total',:] = totals_df.sum(axis=0)

# %%
# CHECKPOINT

totals_df.to_csv('totals.csv')
